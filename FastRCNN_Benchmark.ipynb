# %%
from matplotlib import pyplot as plt
import gluoncv
from gluoncv import model_zoo, data, utils
import time
import os

# %%
#test des data sur le model et visualisation des resultats
for img in os.listdir("image"):
    print("\n")
    print('new')
    x, orig_img = data.transforms.presets.rcnn.load_test('image\\'+str(img))
    box_ids, scores, bboxes = net(x)
    start = time.time()      
    ax = utils.viz.plot_bbox(orig_img, bboxes[0], scores[0], box_ids[0], class_names=net.classes)
    end = time.time()
    print(end - start)
# Out:
# new
# 28.7745943069458
#
#
# new
# 31.43459153175354
#
#
# new
# 28.89009714126587
#
#
# new
# 27.246150255203247
#
#
# new
# 27.936225652694702
#
#
# new
# 29.684571266174316
